# %%
import pandas as pd

# %%
ANSWERS_CSV_URL = "https://raw.githubusercontent.com/dawtasso/eu_survey_correlation/refs/heads/main/data/surveys/volume_b_answer_distributions.csv"

# %%
df = pd.read_csv(ANSWERS_CSV_URL)

# %%
df
# Out:
#       sheet_id                                          file_name  \
# 0        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 1        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 2        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 3        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 4        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# ...        ...                                                ...
# 16455     Q6_7                               fl_506_volume_B.xlsx
# 16456     Q6_7                               fl_506_volume_B.xlsx
# 16457     Q6_7                               fl_506_volume_B.xlsx
# 16458     Q6_7                               fl_506_volume_B.xlsx
# 16459     Q6_7                               fl_506_volume_B.xlsx
#
#                                           question_clean  \
# 0      Do you agree or disagree that the green transi...
# ...

# %%
sub_df = df[
    df["question_clean"]
    == "What are the main objectives, in your opinion, for the EU's agriculture and rural development policy? (Multiple answers possible)"
]

# %%
sub_df.answer_label.unique()
# Out:
# array(['Assurer un niveau de vie correct aux agriculteurs',
#        'Créer de la croissance et des emplois dans les zones rurales',
#        'Garantir des prix raisonnables de nourriture pour les consommateurs',
#        'Garantir un approvisionnement alimentaire stable dans l’UE de manière constante',
#        'Assurer une façon durable de produire des aliments',
#        "Protéger l'environnement et lutter contre le changement climatique",
#        'Fournir de la nourriture durable, sûre, saine et de grande qualité',
#        'Autre (SPONTANÉ)', 'Ne sait pas',
#        'Ensuring a fair standard of living for farmers',
#        'Creating growth and jobs in rural areas',
#        'Ensuring reasonable food prices for consumers',
#        'Securing a stable supply of food in the EU',
#        'Ensuring a sustainable way to produce food',
#        'Protecting the environment and tackling climate change',
#        'Providing safe, healthy food of high quality', 'Other (M)',
# ...

# %%
sub_df
# Out:
#       sheet_id                                   file_name  \
# 4460       QA4  Lien_vers_CAP_2022_eb_sp_520_volume_B.xlsx
# 4461       QA4  Lien_vers_CAP_2022_eb_sp_520_volume_B.xlsx
# 4462       QA4  Lien_vers_CAP_2022_eb_sp_520_volume_B.xlsx
# 4463       QA4  Lien_vers_CAP_2022_eb_sp_520_volume_B.xlsx
# 4464       QA4  Lien_vers_CAP_2022_eb_sp_520_volume_B.xlsx
# ...        ...                                         ...
# 13745       T6                       ebs_504_volume_B.xlsx
# 13746       T6                       ebs_504_volume_B.xlsx
# 13747       T6                       ebs_504_volume_B.xlsx
# 13748       T6                       ebs_504_volume_B.xlsx
# 13749       T6                       ebs_504_volume_B.xlsx
#
#                                           question_clean  \
# 4460   What are the main objectives, in your opinion,...
# 4461   What are the main objectives, in your opinion,...
# 4462   What are the main objectives, in your opinion,...
# ...

# %%
GITHUB_CSV_URL = "https://raw.githubusercontent.com/dawtasso/eu_survey_correlation/refs/heads/main/data/matches/simplified_michlou_survey_vote_matches_clean.csv"

# %%
match_df = pd.read_csv(GITHUB_CSV_URL)

# %%
match_df[
    match_df["question_clean"]
    == "What are the main objectives, in your opinion, for the EU's agriculture and rural development policy? (Multiple answers possible)"
]
# Out:
#    sheet_id                                     question_clean  \
# 19       T6  What are the main objectives, in your opinion,...
# 24       T6  What are the main objectives, in your opinion,...
# 26       T6  What are the main objectives, in your opinion,...
# 68       T6  What are the main objectives, in your opinion,...
#
#                                           question_en              file_name  \
# 19  QA4 In your opinion, which of the following sh...  ebs_504_volume_B.xlsx
# 24  QA4 In your opinion, which of the following sh...  ebs_504_volume_B.xlsx
# 26  QA4 In your opinion, which of the following sh...  ebs_504_volume_B.xlsx
# 68  QA4 In your opinion, which of the following sh...  ebs_504_volume_B.xlsx
#
#    survey_date  vote_id                                            summary  \
# 19  2020-11-27   176981  The European Parliament adopted by 622 votes t...
# 24  2020-11-27   155937  The EU must become food self-sufficient\nInves...
# ...
